# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the dataset

# %%
data1=pd.read_csv('C:\\Users\\USER\\Desktop\\sonl\\Training_set_songs.csv')
data1.head(5)
# Out:
#    Year      TA01      TA02      TA03      TA04      TA05      TA06      TA07  \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#        TA08      TA09  ...      TC69       TC70      TC71      TC72      TC73  \
# 0 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344   1.11144
# 1  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 2  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 3 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 4  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
#
# ...

# %%
data2=pd.read_csv('C:\\Users\\USER\\Desktop\\sonl\\Testing_set_songs.csv')
data2.head(5)
# Out:
#        TA01      TA02      TA03      TA04      TA05      TA06      TA07  \
# 0  45.44200 -30.74976  31.78587   4.63569 -15.14894   0.23370 -11.97968
# 1  52.67814  -2.88914  43.95268  -1.39209 -14.93379 -15.86877   1.19379
# 2  45.74235  12.02291  11.03009 -11.60763  11.80054 -11.12389  -5.39058
# 3  52.55883   2.87222  27.38848  -5.76235 -15.35766 -15.01592  -5.86893
# 4  51.34809   9.02702  25.33757  -6.62537   0.03367 -12.69565  -3.13400
#
#       TA08     TA09     TA10  ...     TC69      TC70       TC71      TC72  \
# 0 -9.59708  6.48111 -8.89073  ... -8.84046  -0.15439  137.44210  77.54739
# 1  0.31401 -4.44235 -5.78934  ... -5.74356 -42.57910   -2.91103  48.72805
# 2 -1.11981 -7.74086 -3.33421  ... -4.70606 -24.22599  -35.22686  27.77729
# 3 -0.31447 -5.06922 -4.62734  ... -8.35215 -16.86791  -10.58277  40.10173
# 4  2.98649 -6.71750 -1.85804  ... -6.87366 -20.03371  -66.38940  50.56569
#
#        TC73      TC74      TC75      TC76      TC77     TC78
# ...

# %%
data=pd.merge(data1,data2.drop_duplicates(['TA01','TA02','TA03','TA04','TC69','TC70','TC71','TC72','TC73','TC74','TC75','TC76','TC77','TC78']),on='TA01',how='left')
data.head()
# Out:
#    Year      TA01    TA02_x    TA03_x    TA04_x    TA05_x    TA06_x    TA07_x  \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#      TA08_x    TA09_x  ...  TC69_y  TC70_y  TC71_y  TC72_y  TC73_y  TC74_y  \
# 0 -12.23257   7.83089  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 1  -0.92019  18.76548  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2  -2.35035  16.07017  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3 -10.34124   3.55005  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4  -9.37636  12.63699  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#    TC75_y  TC76_y  TC77_y  TC78_y
# ...

# %%
df=data.dropna()

# %%
len(df)
# Out:
# 12139

# %%
df.shape
# Out:
# (12139, 180)

# %%
df.describe()
# Out:
#                Year          TA01        TA02_x        TA03_x        TA04_x  \
# count  12139.000000  12139.000000  12139.000000  12139.000000  12139.000000
# mean    1998.734904     44.739554      8.270474      9.525572      1.906583
# std       10.538597      4.079024     43.442510     31.546779     14.816544
# min     1927.000000     23.007800   -269.577960   -139.494670    -61.176970
# 25%     1995.000000     42.195660    -16.541005     -9.147725     -7.480035
# 50%     2002.000000     45.106710     12.636950     10.342370      0.129770
# 75%     2006.000000     47.700090     37.474420     28.521515      9.032555
# max     2010.000000     54.024830    178.084120    224.576280    140.819070
#
#              TA05_x        TA06_x        TA07_x        TA08_x        TA09_x  \
# count  12139.000000  12139.000000  12139.000000  12139.000000  12139.000000
# mean      -7.628428     -9.538032     -1.585679     -2.275098      4.302965
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12139 entries, 25 to 463898
# Columns: 180 entries, Year to TC78_y
# dtypes: float64(179), int64(1)
# memory usage: 16.8 MB

# %% [markdown]
# # Preprocessing of data

# %%
df.isnull().sum()
# Out:
# Year      0
# TA01      0
# TA02_x    0
# TA03_x    0
# TA04_x    0
#          ..
# TC74_y    0
# TC75_y    0
# TC76_y    0
# TC77_y    0
# TC78_y    0
# Length: 180, dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %%
import seaborn as sns

# %%
sns.displot(df['Year'])

# %%
sns.displot(df['TA01'])

# %%
sns.distplot(df['TC74_y'])
# Out:
# C:\Users\USER\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TC74_y', ylabel='Density'>

# %%
sns.distplot(df['TC75_y'])
# Out:
# C:\Users\USER\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TC75_y', ylabel='Density'>

# %%
sns.distplot(df['TC78_y'])
# Out:
# C:\Users\USER\ANACONDA\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TC78_y', ylabel='Density'>

# %% [markdown]
# # Correlation matrix

# %%
df.corr()
# Out:
#             Year      TA01    TA02_x    TA03_x    TA04_x    TA05_x    TA06_x  \
# Year    1.000000  0.216441 -0.045586 -0.202694 -0.037699  0.047474 -0.159769
# TA01    0.216441  1.000000  0.459817  0.213271 -0.111278 -0.187836 -0.324886
# TA02_x -0.045586  0.459817  1.000000 -0.051783  0.047068 -0.095137 -0.140441
# TA03_x -0.202694  0.213271 -0.051783  1.000000  0.112239 -0.162320  0.023495
# TA04_x -0.037699 -0.111278  0.047068  0.112239  1.000000  0.072114  0.310147
# ...          ...       ...       ...       ...       ...       ...       ...
# TC74_y -0.018036 -0.053414 -0.030140 -0.014495  0.018555 -0.004461  0.038990
# TC75_y  0.009183  0.028763  0.009896  0.020623 -0.009507 -0.020907 -0.014942
# TC76_y -0.042703 -0.116295 -0.052279 -0.032267 -0.002897  0.010506  0.043641
# TC77_y -0.019153 -0.101515 -0.051696 -0.014696  0.019720  0.013157  0.044460
# TC78_y -0.004747 -0.116341 -0.076576 -0.021801  0.004700  0.000150  0.040747
#
# ...

# %%
# Out:
# <AxesSubplot:>
